# %%
import numpy as np
import pandas as pd
import os
import lightgbm as lgb
from sklearn.model_selection import train_test_split, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score
from lib.preprocess import Preprocess, data_augmentation
from sklearn.manifold import TSNE
from sklearn.utils import compute_sample_weight
import shap
import optuna
from functools import partial

# %%
SEED = 314
datasrc = "data/official/"
data = pd.read_csv(os.path.join(datasrc, "train.csv"), index_col=0)
x_test = pd.read_csv(os.path.join(datasrc, "test.csv"), index_col=0)
train, valid = train_test_split(data, test_size=0.2, random_state=42, stratify=data["health"])

# %%
x_train = train.drop("health", axis=1)
y_train = train["health"]
x_valid = valid.drop("health", axis=1)
y_valid = valid["health"]

# %%
ignore_columns = [
    "nta_name",
    "boro_ct",
    "spc_latin",
]
# get object columns
object_columns = [col for col in x_train.select_dtypes(include=["object"]).columns.tolist() if col not in ignore_columns]
config = {
    "object_columns": object_columns,
    "is_target_encode": False,
}

# %%
def mean_f1score(preds:np.ndarray,eval_data: lgb.Dataset):
    y_true = eval_data.get_label()
    weight = eval_data.get_weight()
    preds = preds.reshape(len(np.unique(y_true)), -1)
    preds = preds.argmax(axis = 0)
    f1 = f1_score(y_true,preds,average='macro',sample_weight=weight)
    return 'f1',f1,True

# %%
preprocess = Preprocess(config)
skfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=SEED)
noisy_idx = list()

# %%
for train_index, valid_index in skfold.split(x_train, y_train):
    x_train_fold = x_train.iloc[train_index]
    y_train_fold = y_train.iloc[train_index]
    x_valid_fold = x_train.iloc[valid_index]
    y_valid_fold = y_train.iloc[valid_index]
    x_train_fold = preprocess.fit_transform(x_train_fold, y_train_fold)
    x_valid_fold = preprocess.transform(x_valid_fold)
    lgb_train = lgb.Dataset(x_train_fold, y_train_fold, weight=compute_sample_weight("balanced", y_train_fold))
    params = {
        'objective': 'multiclass',
        'metric': None,
        'num_class': 3,
        'seed': 42,
        'num_threads': -1,
    }
    model = lgb.train(
        params,
        lgb_train,
        valid_sets=[lgb_train],
        valid_names=['train'],
        num_boost_round=1000,
        # early_stopping_rounds=100,
        # verbose_eval=100,
        feval=mean_f1score,
        callbacks=[
            lgb.early_stopping(stopping_rounds=100, verbose=False),
            # lgb.reset_parameter(learning_rate=lambda current_round: 0.01 * 0.995 ** current_round),
        ]
    )
    y_pred = model.predict(x_valid_fold)
    y_pred = pd.Series(y_pred.argmax(axis=1), index=y_valid_fold.index)
    print(f1_score(y_valid_fold, y_pred, average='macro'))
    # noisy_idx+=list(set(y_valid_fold.loc[y_valid_fold==0].index)&set(y_pred.loc[y_pred==1].index))
    # noisy_idx+=list(set(y_valid_fold.loc[y_valid_fold==0].index)&set(y_pred.loc[y_pred==2].index))
    noisy_idx+=list(set(y_valid_fold.loc[y_valid_fold==1].index)&set(y_pred.loc[y_pred==0].index))
    noisy_idx+=list(set(y_valid_fold.loc[y_valid_fold==1].index)&set(y_pred.loc[y_pred==2].index))
    # noisy_idx+=list(set(y_valid_fold.loc[y_valid_fold==2].index)&set(y_pred.loc[y_pred==0].index))
    # noisy_idx+=list(set(y_valid_fold.loc[y_valid_fold==2].index)&set(y_pred.loc[y_pred==1].index))
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000581 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1347
# [LightGBM] [Info] Number of data points in the train set: 14388, number of used features: 35
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# 0.34467962629744325
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000658 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1353
# [LightGBM] [Info] Number of data points in the train set: 14388, number of used features: 35
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# 0.32988295877746426
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000587 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1349
# [LightGBM] [Info] Number of data points in the train set: 14388, number of used features: 35
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# 0.32876917765269403
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000768 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1349
# [LightGBM] [Info] Number of data points in the train set: 14388, number of used features: 35
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# 0.33982905982905987
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000681 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1351
# [LightGBM] [Info] Number of data points in the train set: 14388, number of used features: 35
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# 0.32222707539412376
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000810 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1346
# [LightGBM] [Info] Number of data points in the train set: 14388, number of used features: 35
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# 0.32178910799135135
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000739 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 14388, number of used features: 35
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# 0.33600694639655676
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001407 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 14389, number of used features: 35
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# 0.3314791984658135
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001247 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1347
# [LightGBM] [Info] Number of data points in the train set: 14389, number of used features: 35
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# 0.3270905898915793
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001761 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1351
# [LightGBM] [Info] Number of data points in the train set: 14389, number of used features: 35
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# 0.34004483484571274

# %%
# 1->2のデータは害悪なので、それを除いて再度学習
len(noisy_idx)
# Out:
# 1484

# %%
train = train.drop(noisy_idx)
x_train = train.drop("health", axis=1)
y_train = train["health"]

# %%
def kfold_cv(params:dict,x_train:pd.DataFrame,y_train:pd.Series,preprocess:Preprocess):
    skf = StratifiedKFold(n_splits=5,shuffle=True,random_state=42)
    #この関数内ではuserwarningを非表示にする
    import warnings
    warnings.simplefilter('ignore')

    #損失を記録するリスト
    losses = []
    #各foldで学習
    for train_index,test_index in skf.split(x_train,y_train):
        #train,testのデータを作成
        X_train_fold,X_test_fold = x_train.iloc[train_index],x_train.iloc[test_index]
        Y_train_fold,Y_test_fold = y_train.iloc[train_index],y_train.iloc[test_index]

        #前処理
        X_train_fold = preprocess.fit_transform(X_train_fold, Y_train_fold)
        X_test_fold = preprocess.transform(X_test_fold)

        X_train_fold = pd.DataFrame(X_train_fold,columns=preprocess.get_feature_names_out())
        X_test_fold = pd.DataFrame(X_test_fold,columns=preprocess.get_feature_names_out())


        cat_cols = X_train_fold.filter(like='cat__').columns.tolist()
        #カテゴリー変数をカテゴリー型のデータに変換
        for col in cat_cols:
            X_train_fold[col] = X_train_fold[col].astype('category')
            X_test_fold[col] = pd.Categorical(X_test_fold[col],categories=X_train_fold[col].cat.categories)


        #dataset,add competition weight using sklearn
        trainset = lgb.Dataset(X_train_fold,label=Y_train_fold,weight=compute_sample_weight(class_weight='balanced',y=Y_train_fold))
        # trainset = lgb.Dataset(X_train_fold,label=Y_train_fold)
        testset = lgb.Dataset(X_test_fold,label=Y_test_fold,reference=trainset)

        #モデルを作成
        model = lgb.train(params,trainset,num_boost_round=10000,valid_sets=[trainset,testset],valid_names=['train','test'],callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)],feval=mean_f1score)
        #testデータで予測
        preds = model.predict(X_test_fold,num_iteration=model.best_iteration)
        preds = np.argmax(preds,axis=1)
        #f1スコアを計算
        f1 = f1_score(Y_test_fold,preds,average='macro')
        #f1スコアを記録
        losses.append(f1)
    #f1スコアの平均を返す
    return np.mean(losses)

# %%
def objective(x,y,preprocess,trial:optuna.trial):
    # ハイパーパラメータの探索範囲
    params = {
        'objective': 'multiclass',
        'metric': "None",
        'num_class': 3,
        'seed': 42,
        # search space from https://github.com/optuna/optuna-examples/blob/main/lightgbm/lightgbm_integration.py
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
    }
    # 交差検証のF1スコアの平均値を返す
    return kfold_cv(params,x,y,preprocess)

# %%
objective_fixed = partial(objective,x_train,y_train,preprocess)
study = optuna.create_study(direction='maximize')
study.optimize(
    objective_fixed,
    n_trials=300,
    )
# Out:
# [I 2024-01-06 12:31:51,836] A new study created in memory with name: no-name-bc499166-d1c2-4e85-906e-0265149389e4
# [I 2024-01-06 12:32:25,441] Trial 0 finished with value: 0.3883946164288831 and parameters: {'lambda_l1': 7.278796815409793e-05, 'lambda_l2': 0.0004812898903339017, 'num_leaves': 100, 'feature_fraction': 0.6047489481407352, 'bagging_fraction': 0.9294483514739568, 'bagging_freq': 3, 'min_child_samples': 23}. Best is trial 0 with value: 0.3883946164288831.
# [I 2024-01-06 12:33:06,348] Trial 1 finished with value: 0.3955519320837259 and parameters: {'lambda_l1': 0.010056757172005099, 'lambda_l2': 0.0023122302347957173, 'num_leaves': 97, 'feature_fraction': 0.483038600836708, 'bagging_fraction': 0.9022549698999205, 'bagging_freq': 6, 'min_child_samples': 59}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:33:38,457] Trial 2 finished with value: 0.3910343850191886 and parameters: {'lambda_l1': 1.5176652123971455e-06, 'lambda_l2': 3.738330625529465, 'num_leaves': 82, 'feature_fraction': 0.4126346369377111, 'bagging_fraction': 0.7031226015072648, 'bagging_freq': 6, 'min_child_samples': 36}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:34:02,441] Trial 3 finished with value: 0.38501445282748903 and parameters: {'lambda_l1': 5.328730436123001e-07, 'lambda_l2': 3.623198667920895e-07, 'num_leaves': 164, 'feature_fraction': 0.7458591757771453, 'bagging_fraction': 0.6568639486680969, 'bagging_freq': 2, 'min_child_samples': 94}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:34:30,590] Trial 4 finished with value: 0.3895868020050986 and parameters: {'lambda_l1': 2.0571770905887856, 'lambda_l2': 0.0404244038591288, 'num_leaves': 239, 'feature_fraction': 0.4496975012860349, 'bagging_fraction': 0.845780743126433, 'bagging_freq': 5, 'min_child_samples': 50}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:34:57,460] Trial 5 finished with value: 0.390291253700844 and parameters: {'lambda_l1': 0.016036249804363467, 'lambda_l2': 1.3372413671311478, 'num_leaves': 101, 'feature_fraction': 0.6901902274917019, 'bagging_fraction': 0.9866078924552333, 'bagging_freq': 3, 'min_child_samples': 86}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:35:23,825] Trial 6 finished with value: 0.3821777195150223 and parameters: {'lambda_l1': 2.0331710269801662e-05, 'lambda_l2': 2.8933226295700187e-07, 'num_leaves': 190, 'feature_fraction': 0.8682887428150372, 'bagging_fraction': 0.5972594329983927, 'bagging_freq': 5, 'min_child_samples': 72}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:35:54,964] Trial 7 finished with value: 0.38926479914285894 and parameters: {'lambda_l1': 0.010708504352918435, 'lambda_l2': 6.827690238024009e-08, 'num_leaves': 131, 'feature_fraction': 0.571298518627793, 'bagging_fraction': 0.9919552084415185, 'bagging_freq': 4, 'min_child_samples': 83}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:36:25,264] Trial 8 finished with value: 0.39294668111679454 and parameters: {'lambda_l1': 0.004137707607752389, 'lambda_l2': 5.29180486871521e-06, 'num_leaves': 171, 'feature_fraction': 0.453380187806439, 'bagging_fraction': 0.9446842068178423, 'bagging_freq': 2, 'min_child_samples': 73}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:36:53,621] Trial 9 finished with value: 0.3899605692688632 and parameters: {'lambda_l1': 1.8475746576285766e-06, 'lambda_l2': 0.054659387193856254, 'num_leaves': 121, 'feature_fraction': 0.4664876454843472, 'bagging_fraction': 0.7519929766139744, 'bagging_freq': 1, 'min_child_samples': 67}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:37:25,537] Trial 10 finished with value: 0.3760454349618497 and parameters: {'lambda_l1': 1.8677150893764086e-08, 'lambda_l2': 0.00021977480334049116, 'num_leaves': 14, 'feature_fraction': 0.9953195588336354, 'bagging_fraction': 0.40316916368021094, 'bagging_freq': 7, 'min_child_samples': 15}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:37:54,871] Trial 11 finished with value: 0.38973739404836877 and parameters: {'lambda_l1': 0.004097834378326457, 'lambda_l2': 1.3374147058514911e-05, 'num_leaves': 34, 'feature_fraction': 0.5308857280778716, 'bagging_fraction': 0.8663649537422479, 'bagging_freq': 1, 'min_child_samples': 54}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:38:21,511] Trial 12 finished with value: 0.3941136057846017 and parameters: {'lambda_l1': 0.30490778051606104, 'lambda_l2': 4.99235026101401e-05, 'num_leaves': 177, 'feature_fraction': 0.5172156229173364, 'bagging_fraction': 0.8739663503843728, 'bagging_freq': 7, 'min_child_samples': 59}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:38:49,861] Trial 13 finished with value: 0.3895591214576901 and parameters: {'lambda_l1': 0.910808184495693, 'lambda_l2': 0.0007321215791955761, 'num_leaves': 223, 'feature_fraction': 0.5354875927737688, 'bagging_fraction': 0.8445008028520161, 'bagging_freq': 7, 'min_child_samples': 53}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:39:17,642] Trial 14 finished with value: 0.3884347773434914 and parameters: {'lambda_l1': 0.23943400986137095, 'lambda_l2': 0.005603359866948951, 'num_leaves': 51, 'feature_fraction': 0.652692066037619, 'bagging_fraction': 0.7837821069848223, 'bagging_freq': 6, 'min_child_samples': 36}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:39:52,095] Trial 15 finished with value: 0.3914773294777584 and parameters: {'lambda_l1': 6.735800291602123, 'lambda_l2': 1.8494635592331102e-05, 'num_leaves': 148, 'feature_fraction': 0.5162843106012671, 'bagging_fraction': 0.8974183765948289, 'bagging_freq': 6, 'min_child_samples': 63}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:40:22,207] Trial 16 finished with value: 0.3927378448082806 and parameters: {'lambda_l1': 0.18552518183078792, 'lambda_l2': 2.0612713399330313e-08, 'num_leaves': 65, 'feature_fraction': 0.4145701573136126, 'bagging_fraction': 0.806250641622356, 'bagging_freq': 7, 'min_child_samples': 43}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:40:51,877] Trial 17 finished with value: 0.3881708978318284 and parameters: {'lambda_l1': 0.0005490731357642354, 'lambda_l2': 0.00012122488596604596, 'num_leaves': 194, 'feature_fraction': 0.6139312497513394, 'bagging_fraction': 0.9100374406064173, 'bagging_freq': 5, 'min_child_samples': 6}. Best is trial 1 with value: 0.3955519320837259.
# [I 2024-01-06 12:41:24,195] Trial 18 finished with value: 0.3956614320884818 and parameters: {'lambda_l1': 0.060162092621526615, 'lambda_l2': 0.008163638896831197, 'num_leaves': 255, 'feature_fraction': 0.48880801988731926, 'bagging_fraction': 0.8266558671168506, 'bagging_freq': 6, 'min_child_samples': 60}. Best is trial 18 with value: 0.3956614320884818.
# [I 2024-01-06 12:41:56,001] Trial 19 finished with value: 0.3927685895230135 and parameters: {'lambda_l1': 0.03160456577430885, 'lambda_l2': 0.0036229426193371324, 'num_leaves': 214, 'feature_fraction': 0.48338566404644445, 'bagging_fraction': 0.7760367271082281, 'bagging_freq': 4, 'min_child_samples': 100}. Best is trial 18 with value: 0.3956614320884818.
# [I 2024-01-06 12:42:37,700] Trial 20 finished with value: 0.3642649140152652 and parameters: {'lambda_l1': 0.0012108094654827623, 'lambda_l2': 0.02330952565545866, 'num_leaves': 5, 'feature_fraction': 0.4004900006510543, 'bagging_fraction': 0.9513180367481125, 'bagging_freq': 6, 'min_child_samples': 79}. Best is trial 18 with value: 0.3956614320884818.
# [I 2024-01-06 12:43:09,437] Trial 21 finished with value: 0.39119448389541206 and parameters: {'lambda_l1': 0.09243313932488212, 'lambda_l2': 0.1908241206427383, 'num_leaves': 245, 'feature_fraction': 0.5132644987548429, 'bagging_fraction': 0.8680669489117787, 'bagging_freq': 7, 'min_child_samples': 60}. Best is trial 18 with value: 0.3956614320884818.
# [I 2024-01-06 12:43:34,881] Trial 22 finished with value: 0.3928048881830438 and parameters: {'lambda_l1': 0.08695439412872949, 'lambda_l2': 0.001730464469867516, 'num_leaves': 251, 'feature_fraction': 0.5627458178269698, 'bagging_fraction': 0.8956946507749313, 'bagging_freq': 6, 'min_child_samples': 58}. Best is trial 18 with value: 0.3956614320884818.
# [I 2024-01-06 12:44:04,889] Trial 23 finished with value: 0.3940147799939454 and parameters: {'lambda_l1': 0.7708920695669444, 'lambda_l2': 8.734917151621628e-05, 'num_leaves': 202, 'feature_fraction': 0.49684750757758916, 'bagging_fraction': 0.8479664513462127, 'bagging_freq': 5, 'min_child_samples': 44}. Best is trial 18 with value: 0.3956614320884818.
# [I 2024-01-06 12:44:34,307] Trial 24 finished with value: 0.3925401270304377 and parameters: {'lambda_l1': 0.027738390268431452, 'lambda_l2': 0.007480175659021981, 'num_leaves': 130, 'feature_fraction': 0.5709717491825438, 'bagging_fraction': 0.9500578781292555, 'bagging_freq': 7, 'min_child_samples': 68}. Best is trial 18 with value: 0.3956614320884818.
# [I 2024-01-06 12:45:04,433] Trial 25 finished with value: 0.3863736900487181 and parameters: {'lambda_l1': 7.902795180225198, 'lambda_l2': 0.0010729731824846544, 'num_leaves': 160, 'feature_fraction': 0.4634208251169418, 'bagging_fraction': 0.8214350957007379, 'bagging_freq': 6, 'min_child_samples': 31}. Best is trial 18 with value: 0.3956614320884818.
# [I 2024-01-06 12:45:30,174] Trial 26 finished with value: 0.39583272011007997 and parameters: {'lambda_l1': 0.001788020345676441, 'lambda_l2': 0.3205083925598567, 'num_leaves': 106, 'feature_fraction': 0.6171919077511758, 'bagging_fraction': 0.8941367724844428, 'bagging_freq': 4, 'min_child_samples': 76}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:45:54,890] Trial 27 finished with value: 0.3899794721359133 and parameters: {'lambda_l1': 0.0031275896726018293, 'lambda_l2': 0.35991323036902756, 'num_leaves': 99, 'feature_fraction': 0.6164733803682086, 'bagging_fraction': 0.9978815726275623, 'bagging_freq': 4, 'min_child_samples': 89}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:46:21,642] Trial 28 finished with value: 0.39085465106372064 and parameters: {'lambda_l1': 0.00023403635144507345, 'lambda_l2': 9.016913173318729, 'num_leaves': 70, 'feature_fraction': 0.6647866657078779, 'bagging_fraction': 0.9094233730935019, 'bagging_freq': 4, 'min_child_samples': 77}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:46:50,622] Trial 29 finished with value: 0.3886472020548023 and parameters: {'lambda_l1': 0.00012980959514497455, 'lambda_l2': 0.23948684861409436, 'num_leaves': 107, 'feature_fraction': 0.5954669829723054, 'bagging_fraction': 0.9230120616302159, 'bagging_freq': 3, 'min_child_samples': 47}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:47:21,561] Trial 30 finished with value: 0.3910695446085478 and parameters: {'lambda_l1': 0.001721232767437661, 'lambda_l2': 0.009277769265279229, 'num_leaves': 80, 'feature_fraction': 0.5460536457418173, 'bagging_fraction': 0.7971441005425566, 'bagging_freq': 5, 'min_child_samples': 66}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:47:59,733] Trial 31 finished with value: 0.3885070344915134 and parameters: {'lambda_l1': 0.012869239150604965, 'lambda_l2': 0.00046831555058605366, 'num_leaves': 148, 'feature_fraction': 0.5141357916106235, 'bagging_fraction': 0.8773528115513413, 'bagging_freq': 7, 'min_child_samples': 57}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:48:26,268] Trial 32 finished with value: 0.3926949741943999 and parameters: {'lambda_l1': 0.06600176204210473, 'lambda_l2': 0.02068575934762124, 'num_leaves': 117, 'feature_fraction': 0.49019508376261123, 'bagging_fraction': 0.8239669888031182, 'bagging_freq': 6, 'min_child_samples': 72}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:48:58,726] Trial 33 finished with value: 0.39426803332775406 and parameters: {'lambda_l1': 0.2694509606385557, 'lambda_l2': 0.002125066188114487, 'num_leaves': 87, 'feature_fraction': 0.4376005394407557, 'bagging_fraction': 0.8788327149979086, 'bagging_freq': 5, 'min_child_samples': 63}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:49:25,544] Trial 34 finished with value: 0.39069603860424157 and parameters: {'lambda_l1': 0.0005471248190999744, 'lambda_l2': 0.0028752507477163842, 'num_leaves': 92, 'feature_fraction': 0.43303280898892493, 'bagging_fraction': 0.9411872615065409, 'bagging_freq': 5, 'min_child_samples': 80}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:49:58,219] Trial 35 finished with value: 0.3893193912669776 and parameters: {'lambda_l1': 0.01250693965020171, 'lambda_l2': 1.180561916602718, 'num_leaves': 52, 'feature_fraction': 0.43211713972971977, 'bagging_fraction': 0.7404897410568662, 'bagging_freq': 4, 'min_child_samples': 39}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:50:22,921] Trial 36 finished with value: 0.39176433610796896 and parameters: {'lambda_l1': 0.036316976440854194, 'lambda_l2': 0.04199135190058874, 'num_leaves': 86, 'feature_fraction': 0.4051351383779361, 'bagging_fraction': 0.8414915767985798, 'bagging_freq': 5, 'min_child_samples': 29}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:50:50,224] Trial 37 finished with value: 0.3909730255133919 and parameters: {'lambda_l1': 0.00545053725011116, 'lambda_l2': 0.0015406470098323637, 'num_leaves': 141, 'feature_fraction': 0.4656048958123482, 'bagging_fraction': 0.8869926471731484, 'bagging_freq': 3, 'min_child_samples': 89}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:51:14,560] Trial 38 finished with value: 0.39055867994073 and parameters: {'lambda_l1': 6.452040158995793e-05, 'lambda_l2': 0.00043804236398877475, 'num_leaves': 106, 'feature_fraction': 0.7254074877048962, 'bagging_fraction': 0.9662682174143837, 'bagging_freq': 5, 'min_child_samples': 50}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:51:50,376] Trial 39 finished with value: 0.38963517788291957 and parameters: {'lambda_l1': 1.6086783089616044, 'lambda_l2': 0.07261020519968203, 'num_leaves': 117, 'feature_fraction': 0.44097989520677006, 'bagging_fraction': 0.9238309361646957, 'bagging_freq': 4, 'min_child_samples': 74}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:52:16,747] Trial 40 finished with value: 0.3890601714876543 and parameters: {'lambda_l1': 0.007714133011484044, 'lambda_l2': 0.011508977989308297, 'num_leaves': 73, 'feature_fraction': 0.474237118180841, 'bagging_fraction': 0.8226936000087831, 'bagging_freq': 2, 'min_child_samples': 66}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:52:53,167] Trial 41 finished with value: 0.3931005651159239 and parameters: {'lambda_l1': 0.2519265448485898, 'lambda_l2': 0.0030962478905833236, 'num_leaves': 172, 'feature_fraction': 0.49543957272117606, 'bagging_fraction': 0.8671044651485462, 'bagging_freq': 6, 'min_child_samples': 62}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:53:24,804] Trial 42 finished with value: 0.39506624508049437 and parameters: {'lambda_l1': 0.4666101636516293, 'lambda_l2': 0.00020950485040955645, 'num_leaves': 231, 'feature_fraction': 0.5357173883884144, 'bagging_fraction': 0.9734939593993688, 'bagging_freq': 6, 'min_child_samples': 56}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:54:06,558] Trial 43 finished with value: 0.3917655777310276 and parameters: {'lambda_l1': 0.043200619225689484, 'lambda_l2': 0.000383007814249091, 'num_leaves': 230, 'feature_fraction': 0.5447099971147417, 'bagging_fraction': 0.9807020428118801, 'bagging_freq': 5, 'min_child_samples': 52}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:54:34,669] Trial 44 finished with value: 0.3891350993265481 and parameters: {'lambda_l1': 0.6102980400975248, 'lambda_l2': 0.0002305093287360838, 'num_leaves': 256, 'feature_fraction': 0.5761465342742539, 'bagging_fraction': 0.9687371717047122, 'bagging_freq': 6, 'min_child_samples': 71}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:55:08,933] Trial 45 finished with value: 0.3951847137098402 and parameters: {'lambda_l1': 0.12335895538827388, 'lambda_l2': 0.0009895158114595606, 'num_leaves': 241, 'feature_fraction': 0.4425515989205204, 'bagging_fraction': 0.9333412834881647, 'bagging_freq': 6, 'min_child_samples': 56}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:55:41,106] Trial 46 finished with value: 0.3938856110987593 and parameters: {'lambda_l1': 0.01683433020346077, 'lambda_l2': 0.0010319928615212155, 'num_leaves': 235, 'feature_fraction': 0.5437338285454724, 'bagging_fraction': 0.9276798411175495, 'bagging_freq': 6, 'min_child_samples': 56}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:56:10,830] Trial 47 finished with value: 0.3886458351284689 and parameters: {'lambda_l1': 0.11244835812977841, 'lambda_l2': 0.013533802328214094, 'num_leaves': 214, 'feature_fraction': 0.4560500777787856, 'bagging_fraction': 0.9990320348129675, 'bagging_freq': 7, 'min_child_samples': 47}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:56:39,154] Trial 48 finished with value: 0.3935749400693045 and parameters: {'lambda_l1': 3.2316970781709218, 'lambda_l2': 0.0904089172112659, 'num_leaves': 243, 'feature_fraction': 0.5926789606245932, 'bagging_fraction': 0.9633118380154171, 'bagging_freq': 6, 'min_child_samples': 50}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:57:11,237] Trial 49 finished with value: 0.3947588134742809 and parameters: {'lambda_l1': 0.45467956942556415, 'lambda_l2': 0.0001572338232126501, 'num_leaves': 223, 'feature_fraction': 0.49749875806113836, 'bagging_fraction': 0.9249377278036333, 'bagging_freq': 3, 'min_child_samples': 42}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:57:39,756] Trial 50 finished with value: 0.39221805028448675 and parameters: {'lambda_l1': 1.7463780689882655, 'lambda_l2': 0.005037553447673393, 'num_leaves': 188, 'feature_fraction': 0.6234727156030665, 'bagging_fraction': 0.8980183184938553, 'bagging_freq': 6, 'min_child_samples': 68}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:58:09,038] Trial 51 finished with value: 0.39176406433703737 and parameters: {'lambda_l1': 0.5805300716832109, 'lambda_l2': 5.1510548934465584e-05, 'num_leaves': 223, 'feature_fraction': 0.48533253718916036, 'bagging_fraction': 0.9405567419905465, 'bagging_freq': 2, 'min_child_samples': 41}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:58:37,884] Trial 52 finished with value: 0.38988126609590706 and parameters: {'lambda_l1': 0.07310887019874082, 'lambda_l2': 0.0007124741187138333, 'num_leaves': 209, 'feature_fraction': 0.521763621227137, 'bagging_fraction': 0.9261373824598254, 'bagging_freq': 3, 'min_child_samples': 36}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:59:12,828] Trial 53 finished with value: 0.39177770015322366 and parameters: {'lambda_l1': 0.4640157350653115, 'lambda_l2': 0.0002094852648898186, 'num_leaves': 229, 'feature_fraction': 0.4946675455037538, 'bagging_fraction': 0.9638037188260228, 'bagging_freq': 3, 'min_child_samples': 47}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 12:59:41,682] Trial 54 finished with value: 0.38959936223895697 and parameters: {'lambda_l1': 0.15175502255666196, 'lambda_l2': 0.00010492671354090367, 'num_leaves': 242, 'feature_fraction': 0.5548854719707839, 'bagging_fraction': 0.908739124977079, 'bagging_freq': 3, 'min_child_samples': 53}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:00:16,042] Trial 55 finished with value: 0.3893822802927065 and parameters: {'lambda_l1': 0.026449060290363098, 'lambda_l2': 2.4936076213964477e-05, 'num_leaves': 256, 'feature_fraction': 0.5300862842613666, 'bagging_fraction': 0.975060993324125, 'bagging_freq': 6, 'min_child_samples': 55}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:00:50,264] Trial 56 finished with value: 0.3901318847870891 and parameters: {'lambda_l1': 0.1452764669469014, 'lambda_l2': 0.0009123105135019793, 'num_leaves': 219, 'feature_fraction': 0.42307104471105056, 'bagging_fraction': 0.8547401103742751, 'bagging_freq': 1, 'min_child_samples': 32}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:01:17,590] Trial 57 finished with value: 0.3911516993526451 and parameters: {'lambda_l1': 0.007128396048275221, 'lambda_l2': 8.145787606723617e-06, 'num_leaves': 203, 'feature_fraction': 0.45297865962004846, 'bagging_fraction': 0.9443429973093477, 'bagging_freq': 4, 'min_child_samples': 85}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:01:47,651] Trial 58 finished with value: 0.3923927880120627 and parameters: {'lambda_l1': 1.0642894418570645, 'lambda_l2': 0.004022532637048651, 'num_leaves': 249, 'feature_fraction': 0.5115091400691909, 'bagging_fraction': 0.8862232259047101, 'bagging_freq': 2, 'min_child_samples': 22}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:02:18,084] Trial 59 finished with value: 0.39197927849033587 and parameters: {'lambda_l1': 3.6155591871293113, 'lambda_l2': 0.00020441511392802985, 'num_leaves': 184, 'feature_fraction': 0.47434673812197814, 'bagging_fraction': 0.9062441912573108, 'bagging_freq': 7, 'min_child_samples': 60}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:02:50,241] Trial 60 finished with value: 0.3917504329809342 and parameters: {'lambda_l1': 0.002140406690754285, 'lambda_l2': 0.0242187675157563, 'num_leaves': 235, 'feature_fraction': 0.5768651888855029, 'bagging_fraction': 0.9801203132533951, 'bagging_freq': 5, 'min_child_samples': 45}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:03:18,822] Trial 61 finished with value: 0.3956414531452228 and parameters: {'lambda_l1': 0.319121643558515, 'lambda_l2': 0.0022136851445251553, 'num_leaves': 96, 'feature_fraction': 0.4411215072456318, 'bagging_fraction': 0.8764534949136695, 'bagging_freq': 5, 'min_child_samples': 64}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:03:54,708] Trial 62 finished with value: 0.394592211038722 and parameters: {'lambda_l1': 0.3655640885972649, 'lambda_l2': 0.0005929714796662314, 'num_leaves': 122, 'feature_fraction': 0.41335876549947104, 'bagging_fraction': 0.8540270005188038, 'bagging_freq': 6, 'min_child_samples': 64}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:04:31,247] Trial 63 finished with value: 0.39542876522581205 and parameters: {'lambda_l1': 0.06383396798755622, 'lambda_l2': 0.006356579891611115, 'num_leaves': 98, 'feature_fraction': 0.47126957903276995, 'bagging_fraction': 0.9231861375140494, 'bagging_freq': 5, 'min_child_samples': 60}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:04:59,073] Trial 64 finished with value: 0.39401282304648 and parameters: {'lambda_l1': 0.05627307349758699, 'lambda_l2': 0.007030479491970657, 'num_leaves': 60, 'feature_fraction': 0.4501779502313331, 'bagging_fraction': 0.903313919825194, 'bagging_freq': 5, 'min_child_samples': 60}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:05:28,611] Trial 65 finished with value: 0.3929735253581861 and parameters: {'lambda_l1': 0.01976990580341657, 'lambda_l2': 0.019988242233030525, 'num_leaves': 97, 'feature_fraction': 0.4696860430888071, 'bagging_fraction': 0.9461385192302492, 'bagging_freq': 6, 'min_child_samples': 76}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:05:59,155] Trial 66 finished with value: 0.3912195497110299 and parameters: {'lambda_l1': 0.17051257389931732, 'lambda_l2': 0.0018403661756435392, 'num_leaves': 111, 'feature_fraction': 0.40017215841529635, 'bagging_fraction': 0.8822432663831632, 'bagging_freq': 5, 'min_child_samples': 70}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:06:25,759] Trial 67 finished with value: 0.38936932545143194 and parameters: {'lambda_l1': 0.059911532432121786, 'lambda_l2': 0.004511655292521659, 'num_leaves': 36, 'feature_fraction': 0.42453020992748103, 'bagging_fraction': 0.8614021069078946, 'bagging_freq': 5, 'min_child_samples': 58}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:06:55,486] Trial 68 finished with value: 0.3913902411468278 and parameters: {'lambda_l1': 0.025564706243091293, 'lambda_l2': 0.0013876701065332659, 'num_leaves': 78, 'feature_fraction': 0.5308422792481412, 'bagging_fraction': 0.8355306584579405, 'bagging_freq': 6, 'min_child_samples': 63}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:07:27,677] Trial 69 finished with value: 0.3941523011106346 and parameters: {'lambda_l1': 0.0035604205606508408, 'lambda_l2': 0.006938449677375514, 'num_leaves': 141, 'feature_fraction': 0.44923788695282674, 'bagging_fraction': 0.9182367254784699, 'bagging_freq': 4, 'min_child_samples': 82}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:08:02,293] Trial 70 finished with value: 0.39155444292544483 and parameters: {'lambda_l1': 0.012592827591471017, 'lambda_l2': 0.0022935137918522297, 'num_leaves': 95, 'feature_fraction': 0.5114723670532513, 'bagging_fraction': 0.8956239450376667, 'bagging_freq': 7, 'min_child_samples': 68}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:08:34,450] Trial 71 finished with value: 0.39229985946811446 and parameters: {'lambda_l1': 0.39275714782619553, 'lambda_l2': 0.0003945146274282866, 'num_leaves': 108, 'feature_fraction': 0.49848169931316133, 'bagging_fraction': 0.9374463203333838, 'bagging_freq': 4, 'min_child_samples': 50}. Best is trial 26 with value: 0.39583272011007997.
# [I 2024-01-06 13:09:03,383] Trial 72 finished with value: 0.3961131785354127 and parameters: {'lambda_l1': 0.11786733701340335, 'lambda_l2': 0.0007764189853390474, 'num_leaves': 124, 'feature_fraction': 0.4774871371912529, 'bagging_fraction': 0.9242634713292548, 'bagging_freq': 6, 'min_child_samples': 55}. Best is trial 72 with value: 0.3961131785354127.
# [I 2024-01-06 13:09:34,218] Trial 73 finished with value: 0.39023522887966283 and parameters: {'lambda_l1': 0.10302544242850122, 'lambda_l2': 0.0006258123002924712, 'num_leaves': 133, 'feature_fraction': 0.4736346630648156, 'bagging_fraction': 0.9537604852181865, 'bagging_freq': 6, 'min_child_samples': 55}. Best is trial 72 with value: 0.3961131785354127.
# [I 2024-01-06 13:10:03,500] Trial 74 finished with value: 0.39327016224291395 and parameters: {'lambda_l1': 0.21122357645695877, 'lambda_l2': 0.0011770256295589754, 'num_leaves': 124, 'feature_fraction': 0.4340643207093587, 'bagging_fraction': 0.8715507558732899, 'bagging_freq': 6, 'min_child_samples': 61}. Best is trial 72 with value: 0.3961131785354127.
# [I 2024-01-06 13:10:37,914] Trial 75 finished with value: 0.39348173488771443 and parameters: {'lambda_l1': 0.048348260836713425, 'lambda_l2': 0.0021630346813193944, 'num_leaves': 157, 'feature_fraction': 0.46098720167501567, 'bagging_fraction': 0.9904992633903277, 'bagging_freq': 6, 'min_child_samples': 58}. Best is trial 72 with value: 0.3961131785354127.
# [I 2024-01-06 13:11:11,022] Trial 76 finished with value: 0.39258366930388106 and parameters: {'lambda_l1': 0.8573969753661316, 'lambda_l2': 0.010245508134358523, 'num_leaves': 114, 'feature_fraction': 0.4780678972844375, 'bagging_fraction': 0.916823884273595, 'bagging_freq': 5, 'min_child_samples': 65}. Best is trial 72 with value: 0.3961131785354127.
# [I 2024-01-06 13:11:40,062] Trial 77 finished with value: 0.39212085878076225 and parameters: {'lambda_l1': 0.007806696610891001, 'lambda_l2': 0.04176707941744295, 'num_leaves': 87, 'feature_fraction': 0.4199668912968096, 'bagging_fraction': 0.8873199647246914, 'bagging_freq': 7, 'min_child_samples': 52}. Best is trial 72 with value: 0.3961131785354127.
# [I 2024-01-06 13:12:09,659] Trial 78 finished with value: 0.39160445604656124 and parameters: {'lambda_l1': 0.10766016144122866, 'lambda_l2': 0.0036243221598465086, 'num_leaves': 103, 'feature_fraction': 0.44349304381191507, 'bagging_fraction': 0.9515824807125027, 'bagging_freq': 6, 'min_child_samples': 74}. Best is trial 72 with value: 0.3961131785354127.
# [I 2024-01-06 13:12:38,769] Trial 79 finished with value: 0.38897554572755016 and parameters: {'lambda_l1': 0.03578850050676945, 'lambda_l2': 0.0007486086926698415, 'num_leaves': 127, 'feature_fraction': 0.5571834008007684, 'bagging_fraction': 0.931865783914944, 'bagging_freq': 7, 'min_child_samples': 56}. Best is trial 72 with value: 0.3961131785354127.
# [I 2024-01-06 13:13:04,262] Trial 80 finished with value: 0.38705157324401374 and parameters: {'lambda_l1': 0.25755267057701553, 'lambda_l2': 0.00023205251502852645, 'num_leaves': 89, 'feature_fraction': 0.5328655548729129, 'bagging_fraction': 0.8692145684321189, 'bagging_freq': 5, 'min_child_samples': 95}. Best is trial 72 with value: 0.3961131785354127.
# [I 2024-01-06 13:13:36,904] Trial 81 finished with value: 0.39209605736878306 and parameters: {'lambda_l1': 0.359218017540087, 'lambda_l2': 0.00013726543585654744, 'num_leaves': 250, 'feature_fraction': 0.4989816087193831, 'bagging_fraction': 0.915198401180141, 'bagging_freq': 6, 'min_child_samples': 48}. Best is trial 72 with value: 0.3961131785354127.
# [I 2024-01-06 13:14:08,664] Trial 82 finished with value: 0.39002873880011424 and parameters: {'lambda_l1': 0.07609329715366643, 'lambda_l2': 0.00028456321491208465, 'num_leaves': 100, 'feature_fraction': 0.5029911269935544, 'bagging_fraction': 0.9312063309668883, 'bagging_freq': 3, 'min_child_samples': 42}. Best is trial 72 with value: 0.3961131785354127.
# [I 2024-01-06 13:14:40,968] Trial 83 finished with value: 0.400673909336405 and parameters: {'lambda_l1': 0.922099005586728, 'lambda_l2': 0.002626081190204302, 'num_leaves': 236, 'feature_fraction': 0.4780312339088095, 'bagging_fraction': 0.899289347685822, 'bagging_freq': 5, 'min_child_samples': 53}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:15:09,402] Trial 84 finished with value: 0.39541008808799283 and parameters: {'lambda_l1': 1.3980119660942685, 'lambda_l2': 0.0025860901902659945, 'num_leaves': 135, 'feature_fraction': 0.4770945651567631, 'bagging_fraction': 0.8959751011929801, 'bagging_freq': 5, 'min_child_samples': 53}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:15:37,607] Trial 85 finished with value: 0.39034137517335527 and parameters: {'lambda_l1': 1.4323102565928976, 'lambda_l2': 0.0030751454258903326, 'num_leaves': 139, 'feature_fraction': 0.4779110410089936, 'bagging_fraction': 0.8422995777670115, 'bagging_freq': 5, 'min_child_samples': 52}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:16:11,294] Trial 86 finished with value: 0.39585031233952384 and parameters: {'lambda_l1': 0.9604772984228677, 'lambda_l2': 0.00579628600250417, 'num_leaves': 82, 'feature_fraction': 0.4624242174384392, 'bagging_fraction': 0.8925961969652974, 'bagging_freq': 4, 'min_child_samples': 61}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:16:37,335] Trial 87 finished with value: 0.3945724899570523 and parameters: {'lambda_l1': 0.8305508081880935, 'lambda_l2': 0.014103072893640113, 'num_leaves': 76, 'feature_fraction': 0.4605877001704869, 'bagging_fraction': 0.8964723355462889, 'bagging_freq': 4, 'min_child_samples': 70}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:17:09,369] Trial 88 finished with value: 0.3939842505990675 and parameters: {'lambda_l1': 2.9540072390463252, 'lambda_l2': 0.008491882649875169, 'num_leaves': 68, 'feature_fraction': 0.4849056051045201, 'bagging_fraction': 0.8550370074343164, 'bagging_freq': 4, 'min_child_samples': 62}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:17:37,941] Trial 89 finished with value: 0.3899951133156546 and parameters: {'lambda_l1': 1.3772009436977048, 'lambda_l2': 0.005605539093846682, 'num_leaves': 83, 'feature_fraction': 0.5148777854311057, 'bagging_fraction': 0.8779209773602703, 'bagging_freq': 4, 'min_child_samples': 64}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:18:12,151] Trial 90 finished with value: 0.38918954905262215 and parameters: {'lambda_l1': 5.97030755716447, 'lambda_l2': 0.02425657068425671, 'num_leaves': 60, 'feature_fraction': 0.4254919655057271, 'bagging_fraction': 0.8308260141499718, 'bagging_freq': 4, 'min_child_samples': 66}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:18:39,707] Trial 91 finished with value: 0.3891471408704609 and parameters: {'lambda_l1': 0.15813006908855182, 'lambda_l2': 0.0010701649220314726, 'num_leaves': 104, 'feature_fraction': 0.43956849175270757, 'bagging_fraction': 0.8941445666469977, 'bagging_freq': 5, 'min_child_samples': 54}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:19:07,895] Trial 92 finished with value: 0.3947670042126852 and parameters: {'lambda_l1': 0.9121905323376821, 'lambda_l2': 0.0018547877243692496, 'num_leaves': 93, 'feature_fraction': 0.46517505985524094, 'bagging_fraction': 0.9047512252075308, 'bagging_freq': 5, 'min_child_samples': 59}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:19:39,931] Trial 93 finished with value: 0.38988490824637145 and parameters: {'lambda_l1': 2.286894625739618, 'lambda_l2': 0.005011023954607936, 'num_leaves': 116, 'feature_fraction': 0.48755898141492726, 'bagging_fraction': 0.8628628738810636, 'bagging_freq': 5, 'min_child_samples': 49}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:20:13,939] Trial 94 finished with value: 0.3934369277988542 and parameters: {'lambda_l1': 0.22401921253057386, 'lambda_l2': 0.001542140526230428, 'num_leaves': 239, 'feature_fraction': 0.4104901329393539, 'bagging_fraction': 0.9131329543287375, 'bagging_freq': 4, 'min_child_samples': 45}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:20:47,286] Trial 95 finished with value: 0.39396744412387597 and parameters: {'lambda_l1': 0.01610657513242372, 'lambda_l2': 0.003167457715219668, 'num_leaves': 151, 'feature_fraction': 0.44853350561909955, 'bagging_fraction': 0.8797274866005792, 'bagging_freq': 5, 'min_child_samples': 57}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:21:18,926] Trial 96 finished with value: 0.39126405005670833 and parameters: {'lambda_l1': 0.7209302587092483, 'lambda_l2': 0.009086009901351496, 'num_leaves': 82, 'feature_fraction': 0.4617528173649862, 'bagging_fraction': 0.8477057273965694, 'bagging_freq': 5, 'min_child_samples': 54}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:21:47,130] Trial 97 finished with value: 0.3893580617578125 and parameters: {'lambda_l1': 0.11420383120071283, 'lambda_l2': 0.0005662721422875894, 'num_leaves': 44, 'feature_fraction': 0.43256861197928453, 'bagging_fraction': 0.8133161159263456, 'bagging_freq': 4, 'min_child_samples': 61}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:22:15,811] Trial 98 finished with value: 0.3926878040150791 and parameters: {'lambda_l1': 0.04298604132047941, 'lambda_l2': 0.0030258920433959783, 'num_leaves': 112, 'feature_fraction': 0.48015773622502855, 'bagging_fraction': 0.934789033954075, 'bagging_freq': 6, 'min_child_samples': 52}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:22:47,723] Trial 99 finished with value: 0.39010044600465144 and parameters: {'lambda_l1': 0.3564670928947958, 'lambda_l2': 0.014814376662168602, 'num_leaves': 120, 'feature_fraction': 0.5048172548848296, 'bagging_fraction': 0.9569505228757157, 'bagging_freq': 5, 'min_child_samples': 68}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:23:16,206] Trial 100 finished with value: 0.39262901219921 and parameters: {'lambda_l1': 0.022052149953560873, 'lambda_l2': 0.0009036826623061614, 'num_leaves': 134, 'feature_fraction': 0.445967333573542, 'bagging_fraction': 0.9051932150703516, 'bagging_freq': 4, 'min_child_samples': 59}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:23:47,370] Trial 101 finished with value: 0.39275965073267416 and parameters: {'lambda_l1': 0.6669376183543546, 'lambda_l2': 0.00035044280212845455, 'num_leaves': 229, 'feature_fraction': 0.5248912439842506, 'bagging_fraction': 0.9706980423017612, 'bagging_freq': 6, 'min_child_samples': 56}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:24:23,034] Trial 102 finished with value: 0.39518655488001725 and parameters: {'lambda_l1': 0.29524244292951723, 'lambda_l2': 0.0014686100089122802, 'num_leaves': 244, 'feature_fraction': 0.491811725736791, 'bagging_fraction': 0.9219686142980668, 'bagging_freq': 6, 'min_child_samples': 51}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:24:56,452] Trial 103 finished with value: 0.3890787651345418 and parameters: {'lambda_l1': 0.2345636280286416, 'lambda_l2': 0.0021485599662878496, 'num_leaves': 245, 'feature_fraction': 0.4692664315422191, 'bagging_fraction': 0.9205463984773664, 'bagging_freq': 6, 'min_child_samples': 39}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:25:31,563] Trial 104 finished with value: 0.3959313794317867 and parameters: {'lambda_l1': 0.07582676623128597, 'lambda_l2': 0.006059662145193479, 'num_leaves': 251, 'feature_fraction': 0.4879609748726724, 'bagging_fraction': 0.8926454437712029, 'bagging_freq': 6, 'min_child_samples': 46}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:26:01,180] Trial 105 finished with value: 0.39284582311448746 and parameters: {'lambda_l1': 0.5002924922443323, 'lambda_l2': 0.006044619293997188, 'num_leaves': 256, 'feature_fraction': 0.4886111580193668, 'bagging_fraction': 0.8864704873533371, 'bagging_freq': 6, 'min_child_samples': 46}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:26:34,646] Trial 106 finished with value: 0.38849437243450813 and parameters: {'lambda_l1': 0.06601564859136853, 'lambda_l2': 0.004683329137951927, 'num_leaves': 249, 'feature_fraction': 0.5158040687556292, 'bagging_fraction': 0.8708402593712607, 'bagging_freq': 5, 'min_child_samples': 51}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:27:04,686] Trial 107 finished with value: 0.398532517409797 and parameters: {'lambda_l1': 0.037085429710786724, 'lambda_l2': 0.0014249464420042581, 'num_leaves': 109, 'feature_fraction': 0.4934024638630279, 'bagging_fraction': 0.8892611395841868, 'bagging_freq': 6, 'min_child_samples': 49}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:27:35,095] Trial 108 finished with value: 0.394792652546306 and parameters: {'lambda_l1': 0.02918393199988592, 'lambda_l2': 0.034112057213148174, 'num_leaves': 98, 'feature_fraction': 0.45780277560854404, 'bagging_fraction': 0.8900450849662689, 'bagging_freq': 6, 'min_child_samples': 78}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:28:02,806] Trial 109 finished with value: 0.39157762167991306 and parameters: {'lambda_l1': 0.005097040813133397, 'lambda_l2': 0.010264179038920542, 'num_leaves': 108, 'feature_fraction': 0.5052774645538642, 'bagging_fraction': 0.8593480613897522, 'bagging_freq': 5, 'min_child_samples': 48}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:28:30,681] Trial 110 finished with value: 0.3898546701773453 and parameters: {'lambda_l1': 0.08931903583435237, 'lambda_l2': 0.006376581002413745, 'num_leaves': 94, 'feature_fraction': 0.5414518229060059, 'bagging_fraction': 0.9010267163337629, 'bagging_freq': 4, 'min_child_samples': 44}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:29:05,018] Trial 111 finished with value: 0.39533070208261667 and parameters: {'lambda_l1': 0.15800071056149317, 'lambda_l2': 0.0013471447386327249, 'num_leaves': 91, 'feature_fraction': 0.4844432682993264, 'bagging_fraction': 0.9114040426998068, 'bagging_freq': 6, 'min_child_samples': 50}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:29:35,820] Trial 112 finished with value: 0.3902052823580207 and parameters: {'lambda_l1': 0.04449910419535086, 'lambda_l2': 0.0022434785474554895, 'num_leaves': 73, 'feature_fraction': 0.48052490925663705, 'bagging_fraction': 0.8765710106290443, 'bagging_freq': 6, 'min_child_samples': 53}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:30:08,382] Trial 113 finished with value: 0.3966204701009503 and parameters: {'lambda_l1': 0.15255806889865509, 'lambda_l2': 0.003845610534118199, 'num_leaves': 87, 'feature_fraction': 0.46983973139440466, 'bagging_fraction': 0.91250968720377, 'bagging_freq': 6, 'min_child_samples': 62}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:30:40,689] Trial 114 finished with value: 0.39153517278888716 and parameters: {'lambda_l1': 0.012229966586877113, 'lambda_l2': 0.0034773924722622876, 'num_leaves': 105, 'feature_fraction': 0.5243769986549572, 'bagging_fraction': 0.8944932185003771, 'bagging_freq': 6, 'min_child_samples': 61}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:31:14,324] Trial 115 finished with value: 0.39339829675112137 and parameters: {'lambda_l1': 0.05779440617810101, 'lambda_l2': 0.01719968497420819, 'num_leaves': 85, 'feature_fraction': 0.4701548986555738, 'bagging_fraction': 0.8723325749623771, 'bagging_freq': 7, 'min_child_samples': 63}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:31:47,246] Trial 116 finished with value: 0.3892690127946691 and parameters: {'lambda_l1': 0.09381924346296418, 'lambda_l2': 0.012328500704274393, 'num_leaves': 98, 'feature_fraction': 0.5057138945977717, 'bagging_fraction': 0.9444423457811173, 'bagging_freq': 6, 'min_child_samples': 57}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:32:20,271] Trial 117 finished with value: 0.396834424254376 and parameters: {'lambda_l1': 0.02043121063046176, 'lambda_l2': 0.08092873532017315, 'num_leaves': 126, 'feature_fraction': 0.4524601646664666, 'bagging_fraction': 0.8448800970776736, 'bagging_freq': 6, 'min_child_samples': 59}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:32:53,984] Trial 118 finished with value: 0.3950201375221361 and parameters: {'lambda_l1': 0.008247245211422519, 'lambda_l2': 0.08281855676717428, 'num_leaves': 129, 'feature_fraction': 0.41326911671285577, 'bagging_fraction': 0.8545163041859305, 'bagging_freq': 6, 'min_child_samples': 65}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:33:23,085] Trial 119 finished with value: 0.3872237494965115 and parameters: {'lambda_l1': 0.021719134773553035, 'lambda_l2': 0.2227538223752785, 'num_leaves': 121, 'feature_fraction': 0.4584629500676391, 'bagging_fraction': 0.8450657712990638, 'bagging_freq': 6, 'min_child_samples': 8}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:33:57,067] Trial 120 finished with value: 0.3926820927495479 and parameters: {'lambda_l1': 0.027656508241081266, 'lambda_l2': 0.13578282738696346, 'num_leaves': 110, 'feature_fraction': 0.4339769364019797, 'bagging_fraction': 0.8302699683938318, 'bagging_freq': 7, 'min_child_samples': 58}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:34:28,236] Trial 121 finished with value: 0.39456363697682495 and parameters: {'lambda_l1': 0.014447188786708975, 'lambda_l2': 0.007951010567665142, 'num_leaves': 116, 'feature_fraction': 0.45365660771820115, 'bagging_fraction': 0.8846475960122874, 'bagging_freq': 6, 'min_child_samples': 54}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:34:59,679] Trial 122 finished with value: 0.3903969958496334 and parameters: {'lambda_l1': 0.04130204245945185, 'lambda_l2': 0.004099603616515615, 'num_leaves': 20, 'feature_fraction': 0.4967882305289887, 'bagging_fraction': 0.9058357891947293, 'bagging_freq': 6, 'min_child_samples': 60}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:35:29,912] Trial 123 finished with value: 0.3960063806630763 and parameters: {'lambda_l1': 0.1380885171929331, 'lambda_l2': 0.002366630360191246, 'num_leaves': 125, 'feature_fraction': 0.4699196799493493, 'bagging_fraction': 0.9279425268719561, 'bagging_freq': 5, 'min_child_samples': 55}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:36:03,914] Trial 124 finished with value: 0.39398200218213364 and parameters: {'lambda_l1': 0.14206207510331878, 'lambda_l2': 0.06005795537233762, 'num_leaves': 127, 'feature_fraction': 0.4411731229438803, 'bagging_fraction': 0.9264223894194058, 'bagging_freq': 5, 'min_child_samples': 62}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:36:39,060] Trial 125 finished with value: 0.3917998228356841 and parameters: {'lambda_l1': 0.07506571125686123, 'lambda_l2': 0.0006831050742337656, 'num_leaves': 146, 'feature_fraction': 0.423545305016919, 'bagging_fraction': 0.9399812819935857, 'bagging_freq': 6, 'min_child_samples': 66}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:37:11,844] Trial 126 finished with value: 0.3921662383346235 and parameters: {'lambda_l1': 0.19710395383541318, 'lambda_l2': 0.3932246209923011, 'num_leaves': 78, 'feature_fraction': 0.46791833406096045, 'bagging_fraction': 0.9139663230176326, 'bagging_freq': 6, 'min_child_samples': 55}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:37:45,403] Trial 127 finished with value: 0.3959196745636581 and parameters: {'lambda_l1': 0.002488855257956653, 'lambda_l2': 0.03152683218706908, 'num_leaves': 102, 'feature_fraction': 0.45416916435736937, 'bagging_fraction': 0.8627546114224914, 'bagging_freq': 4, 'min_child_samples': 70}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:38:16,824] Trial 128 finished with value: 0.39460574398757653 and parameters: {'lambda_l1': 0.0029374455850111362, 'lambda_l2': 0.03011902924491429, 'num_leaves': 122, 'feature_fraction': 0.450569143143231, 'bagging_fraction': 0.8609380532761215, 'bagging_freq': 4, 'min_child_samples': 75}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:38:51,958] Trial 129 finished with value: 0.39180321233784293 and parameters: {'lambda_l1': 0.004385196544884615, 'lambda_l2': 0.04340088232391957, 'num_leaves': 102, 'feature_fraction': 0.49017970440688047, 'bagging_fraction': 0.8419279148501142, 'bagging_freq': 4, 'min_child_samples': 71}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:39:25,611] Trial 130 finished with value: 0.39143378658211303 and parameters: {'lambda_l1': 0.0012279954104791604, 'lambda_l2': 0.02127288589944861, 'num_leaves': 90, 'feature_fraction': 0.4019394153927538, 'bagging_fraction': 0.8696082958416754, 'bagging_freq': 4, 'min_child_samples': 80}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:40:01,084] Trial 131 finished with value: 0.3928351280001224 and parameters: {'lambda_l1': 0.009313799168034221, 'lambda_l2': 0.01355330361258604, 'num_leaves': 112, 'feature_fraction': 0.4686548665851449, 'bagging_fraction': 0.8186201995557548, 'bagging_freq': 4, 'min_child_samples': 69}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:40:36,024] Trial 132 finished with value: 0.39305698280293205 and parameters: {'lambda_l1': 0.018014588168606953, 'lambda_l2': 0.005308598771824704, 'num_leaves': 101, 'feature_fraction': 0.4538218772398808, 'bagging_fraction': 0.8854735733345691, 'bagging_freq': 5, 'min_child_samples': 64}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 13:41:12,276] Trial 133 finished with value: 0.39294687703711767 and parameters: {'lambda_l1': 0.03510335258556884, 'lambda_l2': 0.0019179155671188808, 'num_leaves': 117, 'feature_fraction': 0.42952064509674187, 'bagging_fraction': 0.9280134546166389, 'bagging_freq': 6, 'min_child_samples': 72}. Best is trial 83 with value: 0.400673909336405.
# ...
# [I 2024-01-06 14:44:57,137] Trial 256 finished with value: 0.3933222201119939 and parameters: {'lambda_l1': 1.4462087771737704, 'lambda_l2': 0.004713635851783116, 'num_leaves': 141, 'feature_fraction': 0.4299439393930165, 'bagging_fraction': 0.9833699626722954, 'bagging_freq': 4, 'min_child_samples': 52}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:45:26,291] Trial 257 finished with value: 0.3920217814102501 and parameters: {'lambda_l1': 0.018417538051018183, 'lambda_l2': 0.015198396780366634, 'num_leaves': 121, 'feature_fraction': 0.44068624033786435, 'bagging_fraction': 0.811446546800721, 'bagging_freq': 6, 'min_child_samples': 45}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:45:53,433] Trial 258 finished with value: 0.3955411162998494 and parameters: {'lambda_l1': 0.07477378707821845, 'lambda_l2': 0.0003335333355968314, 'num_leaves': 84, 'feature_fraction': 0.46450108154990594, 'bagging_fraction': 0.8579297477104815, 'bagging_freq': 5, 'min_child_samples': 61}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:46:51,934] Trial 259 finished with value: 0.3754170749318891 and parameters: {'lambda_l1': 0.0066879225272349855, 'lambda_l2': 0.2000035009894296, 'num_leaves': 5, 'feature_fraction': 0.49965716045638603, 'bagging_fraction': 0.7878064805888937, 'bagging_freq': 6, 'min_child_samples': 59}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:47:20,203] Trial 260 finished with value: 0.39264514136533457 and parameters: {'lambda_l1': 0.032777828874063816, 'lambda_l2': 0.0022977396711062084, 'num_leaves': 93, 'feature_fraction': 0.5841671498275351, 'bagging_fraction': 0.9518291367654674, 'bagging_freq': 6, 'min_child_samples': 76}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:47:53,788] Trial 261 finished with value: 0.3944555873100074 and parameters: {'lambda_l1': 0.7040954237100073, 'lambda_l2': 0.001403904178281494, 'num_leaves': 252, 'feature_fraction': 0.4104217417549594, 'bagging_fraction': 0.9088147270046307, 'bagging_freq': 6, 'min_child_samples': 50}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:48:26,547] Trial 262 finished with value: 0.3908420895232196 and parameters: {'lambda_l1': 0.11980172291186238, 'lambda_l2': 0.006335455210823959, 'num_leaves': 102, 'feature_fraction': 0.523560282881004, 'bagging_fraction': 0.8886839588162294, 'bagging_freq': 6, 'min_child_samples': 64}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:48:54,573] Trial 263 finished with value: 0.3947926612496626 and parameters: {'lambda_l1': 0.052573439722169886, 'lambda_l2': 0.0035257812081719133, 'num_leaves': 74, 'feature_fraction': 0.4795148382904706, 'bagging_fraction': 0.9235608001013689, 'bagging_freq': 6, 'min_child_samples': 56}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:49:25,121] Trial 264 finished with value: 0.3915605715917543 and parameters: {'lambda_l1': 0.0014646278476070063, 'lambda_l2': 0.010035782363804062, 'num_leaves': 87, 'feature_fraction': 0.4472941992641013, 'bagging_fraction': 0.8275361051205395, 'bagging_freq': 7, 'min_child_samples': 47}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:49:52,733] Trial 265 finished with value: 0.3936268464921979 and parameters: {'lambda_l1': 9.392916234975772e-06, 'lambda_l2': 0.05489648325010708, 'num_leaves': 106, 'feature_fraction': 0.46452541131745456, 'bagging_fraction': 0.8742964005668955, 'bagging_freq': 4, 'min_child_samples': 54}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:50:20,700] Trial 266 finished with value: 0.3862565104052684 and parameters: {'lambda_l1': 0.39465979347256164, 'lambda_l2': 0.0010801368732367312, 'num_leaves': 215, 'feature_fraction': 0.5629741275124549, 'bagging_fraction': 0.7055748298494094, 'bagging_freq': 3, 'min_child_samples': 51}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:50:55,605] Trial 267 finished with value: 0.3950188550776213 and parameters: {'lambda_l1': 2.3821727858701096, 'lambda_l2': 0.0018921147468727666, 'num_leaves': 95, 'feature_fraction': 0.4236881316193694, 'bagging_fraction': 0.749494709709355, 'bagging_freq': 6, 'min_child_samples': 58}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:51:27,266] Trial 268 finished with value: 0.3915476438703053 and parameters: {'lambda_l1': 1.0346359713725644, 'lambda_l2': 0.0005029081064789425, 'num_leaves': 132, 'feature_fraction': 0.45202333209704554, 'bagging_fraction': 0.9302219280899647, 'bagging_freq': 5, 'min_child_samples': 90}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:52:02,441] Trial 269 finished with value: 0.39355700696151746 and parameters: {'lambda_l1': 0.0003172968925512264, 'lambda_l2': 0.019062048726527437, 'num_leaves': 79, 'feature_fraction': 0.4935111537871648, 'bagging_fraction': 0.7794796078094909, 'bagging_freq': 6, 'min_child_samples': 43}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:52:34,186] Trial 270 finished with value: 0.3941778058524941 and parameters: {'lambda_l1': 0.010000782196749144, 'lambda_l2': 0.003130814055667434, 'num_leaves': 249, 'feature_fraction': 0.5751458669188833, 'bagging_fraction': 0.8914821272198978, 'bagging_freq': 6, 'min_child_samples': 53}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:53:09,049] Trial 271 finished with value: 0.39356383286253993 and parameters: {'lambda_l1': 0.1721137740059938, 'lambda_l2': 0.724944196081571, 'num_leaves': 89, 'feature_fraction': 0.4340144257132678, 'bagging_fraction': 0.8627345523995952, 'bagging_freq': 4, 'min_child_samples': 62}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:53:37,158] Trial 272 finished with value: 0.3937443972052329 and parameters: {'lambda_l1': 0.0005975968306454197, 'lambda_l2': 0.12484408115262119, 'num_leaves': 70, 'feature_fraction': 0.5484277297173892, 'bagging_fraction': 0.9062129239294754, 'bagging_freq': 6, 'min_child_samples': 69}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:54:13,235] Trial 273 finished with value: 0.3970148358998831 and parameters: {'lambda_l1': 0.027148729829458765, 'lambda_l2': 3.128948193861308e-05, 'num_leaves': 145, 'feature_fraction': 0.472123791412152, 'bagging_fraction': 0.8464178314690062, 'bagging_freq': 6, 'min_child_samples': 49}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:54:45,194] Trial 274 finished with value: 0.3921217176022499 and parameters: {'lambda_l1': 0.024343907115277782, 'lambda_l2': 3.629320889052525e-06, 'num_leaves': 137, 'feature_fraction': 0.4874243398746862, 'bagging_fraction': 0.8446275936481289, 'bagging_freq': 6, 'min_child_samples': 48}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:55:19,691] Trial 275 finished with value: 0.39147881244485805 and parameters: {'lambda_l1': 0.043058818825184524, 'lambda_l2': 0.0008546074101494955, 'num_leaves': 145, 'feature_fraction': 0.4731771241635181, 'bagging_fraction': 0.8334047893973808, 'bagging_freq': 6, 'min_child_samples': 49}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:55:53,352] Trial 276 finished with value: 0.3902336475296698 and parameters: {'lambda_l1': 0.016088043676979667, 'lambda_l2': 0.0001641622867209425, 'num_leaves': 144, 'feature_fraction': 0.47458302054969054, 'bagging_fraction': 0.8508415381437847, 'bagging_freq': 6, 'min_child_samples': 46}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:56:20,985] Trial 277 finished with value: 0.3939412064675793 and parameters: {'lambda_l1': 0.030263336304639486, 'lambda_l2': 0.00023135472900219086, 'num_leaves': 127, 'feature_fraction': 0.509384351839668, 'bagging_fraction': 0.8045595659232398, 'bagging_freq': 6, 'min_child_samples': 51}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:56:55,366] Trial 278 finished with value: 0.39558525665277927 and parameters: {'lambda_l1': 0.05163321787280229, 'lambda_l2': 0.00035383907416905826, 'num_leaves': 227, 'feature_fraction': 0.46115416816391064, 'bagging_fraction': 0.9151546134410564, 'bagging_freq': 6, 'min_child_samples': 55}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:57:24,753] Trial 279 finished with value: 0.38593602860469184 and parameters: {'lambda_l1': 3.810735447769513, 'lambda_l2': 2.600879550690637e-05, 'num_leaves': 179, 'feature_fraction': 0.7812540405571745, 'bagging_fraction': 0.9350786577139325, 'bagging_freq': 6, 'min_child_samples': 79}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:57:54,428] Trial 280 finished with value: 0.39236008371579245 and parameters: {'lambda_l1': 0.016106573083630615, 'lambda_l2': 1.1843189759666538e-08, 'num_leaves': 135, 'feature_fraction': 0.5315007305451792, 'bagging_fraction': 0.8995944316882263, 'bagging_freq': 6, 'min_child_samples': 57}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:58:21,139] Trial 281 finished with value: 0.38811844364415043 and parameters: {'lambda_l1': 0.081230177537691, 'lambda_l2': 3.589791254634531e-05, 'num_leaves': 81, 'feature_fraction': 0.6431339225267012, 'bagging_fraction': 0.9685488703990041, 'bagging_freq': 4, 'min_child_samples': 52}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:58:50,078] Trial 282 finished with value: 0.39457607152964896 and parameters: {'lambda_l1': 1.8781425047302975, 'lambda_l2': 0.32948918410524825, 'num_leaves': 256, 'feature_fraction': 0.48349838723437844, 'bagging_fraction': 0.8183614131479188, 'bagging_freq': 6, 'min_child_samples': 49}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:59:19,374] Trial 283 finished with value: 0.3914069675460551 and parameters: {'lambda_l1': 0.003959126579097716, 'lambda_l2': 0.06571330413147286, 'num_leaves': 122, 'feature_fraction': 0.4101597130479036, 'bagging_fraction': 0.8810784080034044, 'bagging_freq': 6, 'min_child_samples': 54}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 14:59:49,092] Trial 284 finished with value: 0.39151484181202645 and parameters: {'lambda_l1': 0.002163797749017445, 'lambda_l2': 0.00012767847500421046, 'num_leaves': 240, 'feature_fraction': 0.5002729572057021, 'bagging_fraction': 0.9442246913948548, 'bagging_freq': 6, 'min_child_samples': 72}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:00:18,510] Trial 285 finished with value: 0.390337822642845 and parameters: {'lambda_l1': 0.032144685542549574, 'lambda_l2': 5.507318436074256e-07, 'num_leaves': 131, 'feature_fraction': 0.5988283650502891, 'bagging_fraction': 0.8588110489266949, 'bagging_freq': 6, 'min_child_samples': 45}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:00:53,784] Trial 286 finished with value: 0.3908972227893976 and parameters: {'lambda_l1': 0.011388901407908748, 'lambda_l2': 7.141155299206612e-06, 'num_leaves': 116, 'feature_fraction': 0.4511657735172745, 'bagging_fraction': 0.9152312351947708, 'bagging_freq': 6, 'min_child_samples': 41}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:01:23,938] Trial 287 finished with value: 0.385790941914527 and parameters: {'lambda_l1': 0.005870637822846385, 'lambda_l2': 0.0006244701313308636, 'num_leaves': 247, 'feature_fraction': 0.6186001914765129, 'bagging_fraction': 0.8895823832468255, 'bagging_freq': 7, 'min_child_samples': 57}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:01:59,097] Trial 288 finished with value: 0.38831035659920227 and parameters: {'lambda_l1': 1.277496381518517, 'lambda_l2': 1.133986849827593e-05, 'num_leaves': 85, 'feature_fraction': 0.6900901390475536, 'bagging_fraction': 0.8463726350943891, 'bagging_freq': 6, 'min_child_samples': 47}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:02:34,662] Trial 289 finished with value: 0.3932994225132107 and parameters: {'lambda_l1': 0.02127857641701496, 'lambda_l2': 0.005350927626536353, 'num_leaves': 90, 'feature_fraction': 0.4656888447702002, 'bagging_fraction': 0.7625668612268983, 'bagging_freq': 4, 'min_child_samples': 59}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:03:05,559] Trial 290 finished with value: 0.39416017659240576 and parameters: {'lambda_l1': 0.06431924644735076, 'lambda_l2': 0.02464849444731521, 'num_leaves': 109, 'feature_fraction': 0.4001125856676282, 'bagging_fraction': 0.7363268430199879, 'bagging_freq': 6, 'min_child_samples': 52}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:03:37,025] Trial 291 finished with value: 0.3847034242857952 and parameters: {'lambda_l1': 0.9546100234717005, 'lambda_l2': 4.715306256464919e-05, 'num_leaves': 199, 'feature_fraction': 0.41898512584049197, 'bagging_fraction': 0.6274929351002838, 'bagging_freq': 6, 'min_child_samples': 56}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:04:06,792] Trial 292 finished with value: 0.3902395208025816 and parameters: {'lambda_l1': 0.5402485067086024, 'lambda_l2': 0.012266115383071149, 'num_leaves': 76, 'feature_fraction': 0.4764919502817445, 'bagging_fraction': 0.8677401176699415, 'bagging_freq': 6, 'min_child_samples': 50}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:04:38,349] Trial 293 finished with value: 0.3926681477723016 and parameters: {'lambda_l1': 0.10657625576245049, 'lambda_l2': 0.0013594267395500203, 'num_leaves': 99, 'feature_fraction': 0.44464490713614785, 'bagging_fraction': 0.9269571306242101, 'bagging_freq': 6, 'min_child_samples': 54}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:05:10,682] Trial 294 finished with value: 0.39257280474210265 and parameters: {'lambda_l1': 2.6714202889651912, 'lambda_l2': 0.008496757936094607, 'num_leaves': 83, 'feature_fraction': 0.4877400179205723, 'bagging_fraction': 0.8321759437546147, 'bagging_freq': 6, 'min_child_samples': 75}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:05:38,453] Trial 295 finished with value: 0.38489463077479263 and parameters: {'lambda_l1': 0.041821708790934504, 'lambda_l2': 0.0024330063073881845, 'num_leaves': 235, 'feature_fraction': 0.9702500512553234, 'bagging_fraction': 0.9570665505839502, 'bagging_freq': 6, 'min_child_samples': 60}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:06:06,655] Trial 296 finished with value: 0.38829315551425436 and parameters: {'lambda_l1': 5.8189237523978585, 'lambda_l2': 0.0008767138937844327, 'num_leaves': 149, 'feature_fraction': 0.6094320420028925, 'bagging_fraction': 0.9004805497142501, 'bagging_freq': 4, 'min_child_samples': 55}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:06:46,242] Trial 297 finished with value: 0.3951004171772531 and parameters: {'lambda_l1': 0.00884507769056532, 'lambda_l2': 0.001630683045844061, 'num_leaves': 169, 'feature_fraction': 0.4337222059975159, 'bagging_fraction': 0.8816895486380067, 'bagging_freq': 6, 'min_child_samples': 44}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:07:15,805] Trial 298 finished with value: 0.39512723843957276 and parameters: {'lambda_l1': 0.023033409630153108, 'lambda_l2': 0.1635458996623046, 'num_leaves': 95, 'feature_fraction': 0.5152993573541095, 'bagging_fraction': 0.9101235256235279, 'bagging_freq': 6, 'min_child_samples': 48}. Best is trial 83 with value: 0.400673909336405.
# [I 2024-01-06 15:07:45,523] Trial 299 finished with value: 0.39446530944253905 and parameters: {'lambda_l1': 0.20202869113437097, 'lambda_l2': 9.69780300446389e-05, 'num_leaves': 87, 'feature_fraction': 0.45455216877460974, 'bagging_fraction': 0.8713227766902109, 'bagging_freq': 6, 'min_child_samples': 53}. Best is trial 83 with value: 0.400673909336405.

# %%
x_train, x_eval, y_train, y_eval = train_test_split(x_train, y_train, test_size=0.2, random_state=42, stratify=y_train)

x_train = pd.DataFrame(preprocess.fit_transform(x_train, y_train), index=x_train.index, columns=preprocess.get_feature_names_out())
x_eval = pd.DataFrame(preprocess.transform(x_eval), index=x_eval.index, columns=preprocess.get_feature_names_out())
x_valid = pd.DataFrame(preprocess.transform(x_valid), index=x_valid.index, columns=preprocess.get_feature_names_out())
x_test = pd.DataFrame(preprocess.transform(x_test), index=x_test.index, columns=preprocess.get_feature_names_out())
# %%
cat_cols = x_train.filter(like='cat__').columns.tolist()
#カテゴリー変数をカテゴリー型のデータに変換
for col in cat_cols:
    x_train[col] = x_train[col].astype('category')
    x_eval[col] = pd.Categorical(x_eval[col],categories=x_train[col].cat.categories)
    x_valid[col] = pd.Categorical(x_valid[col],categories=x_train[col].cat.categories)
    x_test[col] = pd.Categorical(x_test[col],categories=x_train[col].cat.categories)

# %%
params = study.best_params
params.update({
            'objective': 'multiclass',
            'metric': "None",
            'num_class': 3,
            'verbosity': -1,
            'boosting_type': 'gbdt',
            'seed': 42
            })

# %%
lgb_train = lgb.Dataset(x_train, y_train, weight=compute_sample_weight("balanced", y_train))
lgb_eval = lgb.Dataset(x_eval, y_eval, reference=lgb_train)#", weight=compute_sample_weight("balanced", y_eval))
model = lgb.train(
    params,
    lgb_train,
    valid_sets=[lgb_eval],
    valid_names=['evaluate'],
    num_boost_round=1000,
    # early_stopping_rounds=100,
    # verbose_eval=100,
    feval=mean_f1score,
    callbacks=[
        lgb.early_stopping(stopping_rounds=100, verbose=False),
        # lgb.reset_parameter(learning_rate=lambda current_round: 0.01 * 0.995 ** current_round),
    ]
)

# %%
y_pred = model.predict(x_valid)
y_pred = pd.Series(y_pred.argmax(axis=1), index=y_valid.index)
print(f1_score(y_valid, y_pred, average='macro'))
# Out:
# 0.35910787510880504

# %%
y_pred.value_counts(normalize=True)
# Out:
# 1    0.724543
# 0    0.229672
# 2    0.045784
# dtype: float64

# %%
submit_name = "metha_lgbm"
predict = pd.Series(model.predict(x_test).argmax(axis=1), index=x_test.index)
predict.to_csv(f"submission/{submit_name}_submission.csv",  header=False)
